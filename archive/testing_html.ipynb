# %%
try:
    from IPython.core.display import display as ipython_display, HTML
    have_ipython = True
except ImportError:
    have_ipython = False
# Out:
# /tmp/ipykernel_266796/158450625.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display as ipython_display, HTML

# %%
out = """'<div align=\'center\'>\n
    <script>\n    document._hover_magufbxjkoumibqnftcf = \'_tp_magufbxjkoumibqnftcf_output_0\';\n    document._zoom_magufbxjkoumibqnftcf = undefined;\n    function _output_onclick_magufbxjkoumibqnftcf(i) {\n        var next_id = undefined;\n        \n        if (document._zoom_magufbxjkoumibqnftcf !== undefined) {\n            document.getElementById(document._zoom_magufbxjkoumibqnftcf+ \'_zoom\').style.display = \'none\';\n            \n            if (document._zoom_magufbxjkoumibqnftcf === \'_tp_magufbxjkoumibqnftcf_output_\' + i) {\n                document.getElementById(document._zoom_magufbxjkoumibqnftcf).style.display = \'block\';\n                document.getElementById(document._zoom_magufbxjkoumibqnftcf+\'_name\').style.borderBottom = \'3px solid #000000\';\n            } else {\n                document.getElementById(document._zoom_magufbxjkoumibqnftcf).style.display = \'none\';\n                document.getElementById(document._zoom_magufbxjkoumibqnftcf+\'_name\').style.borderBottom = \'none\';\n            }\n        }\n        if (document._zoom_magufbxjkoumibqnftcf !== \'_tp_magufbxjkoumibqnftcf_output_\' + i) {\n            next_id = \'_tp_magufbxjkoumibqnftcf_output_\' + i;\n            document.getElementById(next_id).style.display = \'none\';\n            document.getElementById(next_id + \'_zoom\').style.display = \'block\';\n            document.getElementById(next_id+\'_name\').style.borderBottom = \'3px solid #000000\';\n        }\n        document._zoom_magufbxjkoumibqnftcf = next_id;\n    }\n    function _output_onmouseover_magufbxjkoumibqnftcf(i, el) {\n        if (document._zoom_magufbxjkoumibqnftcf !== undefined) { return; }\n        if (document._hover_magufbxjkoumibqnftcf !== undefined) {\n            document.getElementById(document._hover_magufbxjkoumibqnftcf + \'_name\').style.borderBottom = \'none\';\n            document.getElementById(document._hover_magufbxjkoumibqnftcf).style.display = \'none\';\n        }\n        document.getElementById(\'_tp_magufbxjkoumibqnftcf_output_\' + i).style.display = \'block\';\n        el.style.borderBottom = \'3px solid #000000\';\n        document._hover_magufbxjkoumibqnftcf = \'_tp_magufbxjkoumibqnftcf_output_\' + i;\n    }\n</script>
    \n<div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>\n<div
        style="display: inline; border-bottom: 3px solid #000000; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px"
        id="_tp_magufbxjkoumibqnftcf_output_0_name" \n onclick="_output_onclick_magufbxjkoumibqnftcf(0)" \n
        onmouseover="_output_onmouseover_magufbxjkoumibqnftcf(0, this);">Negative</div>\n<div
        style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px"
        id="_tp_magufbxjkoumibqnftcf_output_1_name" \n onclick="_output_onclick_magufbxjkoumibqnftcf(1)" \n
        onmouseover="_output_onmouseover_magufbxjkoumibqnftcf(1, this);">Positive</div><br><br>
    <div id=\'_tp_magufbxjkoumibqnftcf_output_0\' style=\'display: block\';><svg width="100%" height="80px">
            <line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" />
            <line x1="49.9999996114866%" y1="33" x2="49.9999996114866%" y2="37"
                style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.9999996114866%" y="27" font-size="12px"
                fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text>
            <line x1="36.91614900790208%" y1="33" x2="36.91614900790208%" y2="37"
                style="stroke:rgb(150,150,150);stroke-width:1" /><text x="36.91614900790208%" y="27" font-size="12px"
                fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text>
            <line x1="23.83229840431756%" y1="33" x2="23.83229840431756%" y2="37"
                style="stroke:rgb(150,150,150);stroke-width:1" /><text x="23.83229840431756%" y="27" font-size="12px"
                fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.1</text>
            <line x1="10.748447800733036%" y1="33" x2="10.748447800733036%" y2="37"
                style="stroke:rgb(150,150,150);stroke-width:1" /><text x="10.748447800733036%" y="27" font-size="12px"
                fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.4</text>
            <line x1="63.08385021507113%" y1="33" x2="63.08385021507113%" y2="37"
                style="stroke:rgb(150,150,150);stroke-width:1" /><text x="63.08385021507113%" y="27" font-size="12px"
                fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text>
            <line x1="76.16770081865565%" y1="33" x2="76.16770081865565%" y2="37"
                style="stroke:rgb(150,150,150);stroke-width:1" /><text x="76.16770081865565%" y="27" font-size="12px"
                fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.1</text>
            <line x1="89.25155142224015%" y1="33" x2="89.25155142224015%" y2="37"
                style="stroke:rgb(150,150,150);stroke-width:1" /><text x="89.25155142224015%" y="27" font-size="12px"
                fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.4</text>
            <line x1="53.64915660883906%" y1="33" x2="53.64915660883906%" y2="37"
                style="stroke:rgb(150,150,150);stroke-width:1" /><text x="53.64915660883906%" y="27" font-size="13px"
                style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom"
                text-anchor="middle">0.583672</text><text x="53.64915660883906%" y="27" font-size="12px"
                fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.583672</text><text
                x="53.64915660883906%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom"
                text-anchor="middle">base value</text>
            <line x1="28.20000827115969%" y1="33" x2="28.20000827115969%" y2="37"
                style="stroke:rgb(150,150,150);stroke-width:1" /><text x="28.20000827115969%" y="27" font-size="13px"
                style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)"
                dominant-baseline="bottom" text-anchor="middle">0.00014735</text><text x="28.20000827115969%" y="27"
                font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom"
                text-anchor="middle">0.00014735</text><text x="28.20000827115969%" y="10" font-size="12px"
                fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub"
                    font-size="8px">Negative</tspan>(inputs)</text>
            <rect x="6.820763739999894%" width="21.37924453115979%" y="40" height="18"
                style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" />
            <line x1="16.259256263986032%" x2="28.20000827115969%" y1="60" y2="60" id="_fb_qyoanfadzygaiohbyluo_ind_12"
                style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0" /><text
                x="22.22963226757286%" y="71" font-size="12px" id="_fs_qyoanfadzygaiohbyluo_ind_12"
                fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle"
                text-anchor="middle">0.274</text><svg x="16.259256263986032%" y="40" height="20"
                width="11.940752007173657%"> <svg x="0" y="0" width="100%" height="100%"> <text x="50%" y="9"
                        font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle"
                        text-anchor="middle">no</text> </svg></svg>
            <line x1="14.207056448000586%" x2="16.259256263986032%" y1="60" y2="60" id="_fb_qyoanfadzygaiohbyluo_ind_5"
                style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0" /><text
                x="15.233156355993309%" y="71" font-size="12px" id="_fs_qyoanfadzygaiohbyluo_ind_5"
                fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle"
                text-anchor="middle">0.047</text><svg x="14.207056448000586%" y="40" height="20"
                width="2.052199815985446%"> <svg x="0" y="0" width="100%" height="100%"> <text x="50%" y="9"
                        font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle"
                        text-anchor="middle">!</text> </svg></svg>
            <line x1="12.327340616260239%" x2="14.207056448000586%" y1="60" y2="60" id="_fb_qyoanfadzygaiohbyluo_ind_1"
                style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0" /><text
                x="13.267198532130411%" y="71" font-size="12px" id="_fs_qyoanfadzygaiohbyluo_ind_1"
                fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle"
                text-anchor="middle">0.043</text><svg x="12.327340616260239%" y="40" height="20"
                width="1.8797158317403468%"> <svg x="0" y="0" width="100%" height="100%"> <text x="50%" y="9"
                        font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle"
                        text-anchor="middle">What</text> </svg></svg>
            <line x1="10.794675405472242%" x2="12.327340616260239%" y1="60" y2="60" id="_fb_qyoanfadzygaiohbyluo_ind_13"
                style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0" /><text
                x="11.56100801086624%" y="71" font-size="12px" id="_fs_qyoanfadzygaiohbyluo_ind_13"
                fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle"
                text-anchor="middle">0.035</text><svg x="10.794675405472242%" y="40" height="20"
                width="1.5326652107879966%"> <svg x="0" y="0" width="100%" height="100%"> <text x="50%" y="9"
                        font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle"
                        text-anchor="middle">taste</text> </svg></svg>
            <line x1="9.521272413294831%" x2="10.794675405472242%" y1="60" y2="60" id="_fb_qyoanfadzygaiohbyluo_ind_14"
                style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0" /><text
                x="10.157973909383536%" y="71" font-size="12px" id="_fs_qyoanfadzygaiohbyluo_ind_14"
                fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle"
                text-anchor="middle">0.029</text><svg x="9.521272413294831%" y="40" height="20"
                width="1.2734029921774113%"> <svg x="0" y="0" width="100%" height="100%"> <text x="50%" y="9"
                        font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle"
                        text-anchor="middle">.</text> </svg></svg>
            <line x1="8.38093454573518%" x2="9.521272413294831%" y1="60" y2="60" id="_fb_qyoanfadzygaiohbyluo_ind_7"
                style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0" /><text
                x="8.951103479515005%" y="71" font-size="12px" id="_fs_qyoanfadzygaiohbyluo_ind_7"
                fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle"
                text-anchor="middle">0.026</text><svg x="8.38093454573518%" y="40" height="20"
                width="1.1403378675596514%"> <svg x="0" y="0" width="100%" height="100%"> <text x="50%" y="9"
                        font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle"
                        text-anchor="middle">.</text> </svg></svg>
            <line x1="7.244200406291928%" x2="8.38093454573518%" y1="60" y2="60" id="_fb_qyoanfadzygaiohbyluo_ind_8"
                style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0" /><text
                x="7.8125674760135535%" y="71" font-size="12px" id="_fs_qyoanfadzygaiohbyluo_ind_8"
                fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle"
                text-anchor="middle">0.026</text><svg x="7.244200406291928%" y="40" height="20"
                width="1.1367341394432513%"> <svg x="0" y="0" width="100%" height="100%"> <text x="50%" y="9"
                        font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle"
                        text-anchor="middle">.</text> </svg></svg>
            <line x1="6.820763739999894%" x2="7.244200406291928%" y1="60" y2="60" id="_fb_qyoanfadzygaiohbyluo_ind_6"
                style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0" /><text
                x="7.032482073145911%" y="71" font-size="12px" id="_fs_qyoanfadzygaiohbyluo_ind_6"
                fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle"
                text-anchor="middle">0.01</text><svg x="6.820763739999894%" y="40" height="20"
                width="0.4234366662920346%"> <svg x="0" y="0" width="100%" height="100%"> <text x="50%" y="9"
                        font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle"
                        text-anchor="middle">.</text> </svg></svg>
            <g transform="translate(0,0)"> <svg x="16.259256263986032%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(2,0)"> <svg x="16.259256263986032%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(4,0)"> <svg x="16.259256263986032%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(6,0)"> <svg x="16.259256263986032%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-8,0)"> <svg x="16.259256263986032%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-6,0)"> <svg x="16.259256263986032%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-4,0)"> <svg x="16.259256263986032%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-2,0)"> <svg x="16.259256263986032%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(0,0)"> <svg x="14.207056448000586%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(2,0)"> <svg x="14.207056448000586%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(4,0)"> <svg x="14.207056448000586%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(6,0)"> <svg x="14.207056448000586%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-8,0)"> <svg x="14.207056448000586%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-6,0)"> <svg x="14.207056448000586%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-4,0)"> <svg x="14.207056448000586%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-2,0)"> <svg x="14.207056448000586%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(0,0)"> <svg x="12.327340616260239%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(2,0)"> <svg x="12.327340616260239%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(4,0)"> <svg x="12.327340616260239%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(6,0)"> <svg x="12.327340616260239%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-8,0)"> <svg x="12.327340616260239%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-6,0)"> <svg x="12.327340616260239%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-4,0)"> <svg x="12.327340616260239%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-2,0)"> <svg x="12.327340616260239%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(0,0)"> <svg x="10.794675405472242%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(2,0)"> <svg x="10.794675405472242%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(4,0)"> <svg x="10.794675405472242%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(6,0)"> <svg x="10.794675405472242%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-8,0)"> <svg x="10.794675405472242%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-6,0)"> <svg x="10.794675405472242%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-4,0)"> <svg x="10.794675405472242%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-2,0)"> <svg x="10.794675405472242%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(0,0)"> <svg x="9.521272413294831%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(2,0)"> <svg x="9.521272413294831%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(4,0)"> <svg x="9.521272413294831%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(6,0)"> <svg x="9.521272413294831%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-8,0)"> <svg x="9.521272413294831%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-6,0)"> <svg x="9.521272413294831%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-4,0)"> <svg x="9.521272413294831%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-2,0)"> <svg x="9.521272413294831%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(0,0)"> <svg x="8.38093454573518%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(2,0)"> <svg x="8.38093454573518%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(4,0)"> <svg x="8.38093454573518%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(6,0)"> <svg x="8.38093454573518%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-8,0)"> <svg x="8.38093454573518%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-6,0)"> <svg x="8.38093454573518%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-4,0)"> <svg x="8.38093454573518%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-2,0)"> <svg x="8.38093454573518%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(0,0)"> <svg x="7.244200406291928%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(2,0)"> <svg x="7.244200406291928%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(4,0)"> <svg x="7.244200406291928%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(6,0)"> <svg x="7.244200406291928%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-8,0)"> <svg x="7.244200406291928%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-6,0)"> <svg x="7.244200406291928%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-4,0)"> <svg x="7.244200406291928%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <g transform="translate(-2,0)"> <svg x="7.244200406291928%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none"
                        style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2" />
                </svg></g>
            <rect transform="translate(-8,0)" x="28.20000827115969%" y="40" width="8" height="18"
                style="fill:rgb(255.0, 0.0, 81.08083606031792)" />
            <g transform="translate(-11.5,0)"> <svg x="6.820763739999894%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 10 -9 l 6 18 L 10 25 L 0 25 L 0 -9" fill="#ffffff"
                        style="stroke:rgb(255,255,255);stroke-width:2" />
                </svg></g>
            <g transform="translate(-1.5,0)"> <svg x="28.20000827115969%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none" style="stroke:rgb(255, 195, 213);stroke-width:2" />
                </svg></g>
            <rect x="16.259256263986032%" y="40" height="20" width="11.940752007173657%"
                onmouseover="document.getElementById(\'_tp_qyoanfadzygaiohbyluo_ind_12\').style.textDecoration = \'underline\';document.getElementById(\'_fs_qyoanfadzygaiohbyluo_ind_12\').style.opacity = 1;document.getElementById(\'_fb_qyoanfadzygaiohbyluo_ind_12\').style.opacity = 1;"
                onmouseout="document.getElementById(\'_tp_qyoanfadzygaiohbyluo_ind_12\').style.textDecoration = \'none\';document.getElementById(\'_fs_qyoanfadzygaiohbyluo_ind_12\').style.opacity = 0;document.getElementById(\'_fb_qyoanfadzygaiohbyluo_ind_12\').style.opacity = 0;"
                style="fill:rgb(0,0,0,0)" />
            <g transform="translate(-1.5,0)"> <svg x="16.259256263986032%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none" style="stroke:rgb(255, 195, 213);stroke-width:2" />
                </svg></g>
            <rect x="14.207056448000586%" y="40" height="20" width="2.052199815985446%"
                onmouseover="document.getElementById(\'_tp_qyoanfadzygaiohbyluo_ind_5\').style.textDecoration = \'underline\';document.getElementById(\'_fs_qyoanfadzygaiohbyluo_ind_5\').style.opacity = 1;document.getElementById(\'_fb_qyoanfadzygaiohbyluo_ind_5\').style.opacity = 1;"
                onmouseout="document.getElementById(\'_tp_qyoanfadzygaiohbyluo_ind_5\').style.textDecoration = \'none\';document.getElementById(\'_fs_qyoanfadzygaiohbyluo_ind_5\').style.opacity = 0;document.getElementById(\'_fb_qyoanfadzygaiohbyluo_ind_5\').style.opacity = 0;"
                style="fill:rgb(0,0,0,0)" />
            <g transform="translate(-1.5,0)"> <svg x="14.207056448000586%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none" style="stroke:rgb(255, 195, 213);stroke-width:2" />
                </svg></g>
            <rect x="12.327340616260239%" y="40" height="20" width="1.8797158317403468%"
                onmouseover="document.getElementById(\'_tp_qyoanfadzygaiohbyluo_ind_1\').style.textDecoration = \'underline\';document.getElementById(\'_fs_qyoanfadzygaiohbyluo_ind_1\').style.opacity = 1;document.getElementById(\'_fb_qyoanfadzygaiohbyluo_ind_1\').style.opacity = 1;"
                onmouseout="document.getElementById(\'_tp_qyoanfadzygaiohbyluo_ind_1\').style.textDecoration = \'none\';document.getElementById(\'_fs_qyoanfadzygaiohbyluo_ind_1\').style.opacity = 0;document.getElementById(\'_fb_qyoanfadzygaiohbyluo_ind_1\').style.opacity = 0;"
                style="fill:rgb(0,0,0,0)" />
            <g transform="translate(-1.5,0)"> <svg x="12.327340616260239%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none" style="stroke:rgb(255, 195, 213);stroke-width:2" />
                </svg></g>
            <rect x="10.794675405472242%" y="40" height="20" width="1.5326652107879966%"
                onmouseover="document.getElementById(\'_tp_qyoanfadzygaiohbyluo_ind_13\').style.textDecoration = \'underline\';document.getElementById(\'_fs_qyoanfadzygaiohbyluo_ind_13\').style.opacity = 1;document.getElementById(\'_fb_qyoanfadzygaiohbyluo_ind_13\').style.opacity = 1;"
                onmouseout="document.getElementById(\'_tp_qyoanfadzygaiohbyluo_ind_13\').style.textDecoration = \'none\';document.getElementById(\'_fs_qyoanfadzygaiohbyluo_ind_13\').style.opacity = 0;document.getElementById(\'_fb_qyoanfadzygaiohbyluo_ind_13\').style.opacity = 0;"
                style="fill:rgb(0,0,0,0)" />
            <g transform="translate(-1.5,0)"> <svg x="10.794675405472242%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none" style="stroke:rgb(255, 195, 213);stroke-width:2" />
                </svg></g>
            <rect x="9.521272413294831%" y="40" height="20" width="1.2734029921774113%"
                onmouseover="document.getElementById(\'_tp_qyoanfadzygaiohbyluo_ind_14\').style.textDecoration = \'underline\';document.getElementById(\'_fs_qyoanfadzygaiohbyluo_ind_14\').style.opacity = 1;document.getElementById(\'_fb_qyoanfadzygaiohbyluo_ind_14\').style.opacity = 1;"
                onmouseout="document.getElementById(\'_tp_qyoanfadzygaiohbyluo_ind_14\').style.textDecoration = \'none\';document.getElementById(\'_fs_qyoanfadzygaiohbyluo_ind_14\').style.opacity = 0;document.getElementById(\'_fb_qyoanfadzygaiohbyluo_ind_14\').style.opacity = 0;"
                style="fill:rgb(0,0,0,0)" />
            <g transform="translate(-1.5,0)"> <svg x="9.521272413294831%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none" style="stroke:rgb(255, 195, 213);stroke-width:2" />
                </svg></g>
            <rect x="8.38093454573518%" y="40" height="20" width="1.1403378675596514%"
                onmouseover="document.getElementById(\'_tp_qyoanfadzygaiohbyluo_ind_7\').style.textDecoration = \'underline\';document.getElementById(\'_fs_qyoanfadzygaiohbyluo_ind_7\').style.opacity = 1;document.getElementById(\'_fb_qyoanfadzygaiohbyluo_ind_7\').style.opacity = 1;"
                onmouseout="document.getElementById(\'_tp_qyoanfadzygaiohbyluo_ind_7\').style.textDecoration = \'none\';document.getElementById(\'_fs_qyoanfadzygaiohbyluo_ind_7\').style.opacity = 0;document.getElementById(\'_fb_qyoanfadzygaiohbyluo_ind_7\').style.opacity = 0;"
                style="fill:rgb(0,0,0,0)" />
            <g transform="translate(-1.5,0)"> <svg x="8.38093454573518%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 0 -9 l 6 18 L 0 25" fill="none" style="stroke:rgb(255, 195, 213);stroke-width:2" />
                </svg></g>
            <rect x="7.244200406291928%" y="40" height="20" width="1.1367341394432513%"
                onmouseover="document.getElementById(\'_tp_qyoanfadzygaiohbyluo_ind_8\').style.textDecoration = \'underline\';document.getElementById(\'_fs_qyoanfadzygaiohbyluo_ind_8\').style.opacity = 1;document.getElementById(\'_fb_qyoanfadzygaiohbyluo_ind_8\').style.opacity = 1;"
                onmouseout="document.getElementById(\'_tp_qyoanfadzygaiohbyluo_ind_8\').style.textDecoration = \'none\';document.getElementById(\'_fs_qyoanfadzygaiohbyluo_ind_8\').style.opacity = 0;document.getElementById(\'_fb_qyoanfadzygaiohbyluo_ind_8\').style.opacity = 0;"
                style="fill:rgb(0,0,0,0)" />
            <rect x="6.820763739999894%" y="40" height="20" width="0.4234366662920346%"
                onmouseover="document.getElementById(\'_tp_qyoanfadzygaiohbyluo_ind_6\').style.textDecoration = \'underline\';document.getElementById(\'_fs_qyoanfadzygaiohbyluo_ind_6\').style.opacity = 1;document.getElementById(\'_fb_qyoanfadzygaiohbyluo_ind_6\').style.opacity = 1;"
                onmouseout="document.getElementById(\'_tp_qyoanfadzygaiohbyluo_ind_6\').style.textDecoration = \'none\';document.getElementById(\'_fs_qyoanfadzygaiohbyluo_ind_6\').style.opacity = 0;document.getElementById(\'_fb_qyoanfadzygaiohbyluo_ind_6\').style.opacity = 0;"
                style="fill:rgb(0,0,0,0)" />
            <rect x="28.20000827115969%" width="46.82839286883917%" y="40" height="18"
                style="fill:rgb(0.0, 138.56128015770727, 250.76166088685727); stroke-width:0; stroke:rgb(0,0,0)" />
            <line x1="28.20000827115969%" x2="60.47883153137376%" y1="60" y2="60" id="_fb_qyoanfadzygaiohbyluo_ind_3"
                style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2; opacity: 0" /><text
                x="44.33941990126672%" y="71" font-size="12px" fill="rgb(0.0, 138.56128015770727, 250.76166088685727)"
                id="_fs_qyoanfadzygaiohbyluo_ind_3" style="opacity: 0" dominant-baseline="middle"
                text-anchor="middle">-0.74</text><svg x="28.20000827115969%" y="40" height="20"
                width="32.27882326021407%"> <svg x="0" y="0" width="100%" height="100%"> <text x="50%" y="9"
                        font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle"
                        text-anchor="middle">great</text> </svg></svg>
            <line x1="60.47883153137376%" x2="65.7495523679232%" y1="60" y2="60" id="_fb_qyoanfadzygaiohbyluo_ind_2"
                style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2; opacity: 0" /><text
                x="63.11419194964848%" y="71" font-size="12px" fill="rgb(0.0, 138.56128015770727, 250.76166088685727)"
                id="_fs_qyoanfadzygaiohbyluo_ind_2" style="opacity: 0" dominant-baseline="middle"
                text-anchor="middle">-0.121</text><svg x="60.47883153137376%" y="40" height="20"
                width="5.270720836549444%"> <svg x="0" y="0" width="100%" height="100%"> <text x="50%" y="9"
                        font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle"
                        text-anchor="middle">a</text> </svg></svg>
            <line x1="65.7495523679232%" x2="70.96946686039661%" y1="60" y2="60" id="_fb_qyoanfadzygaiohbyluo_ind_10"
                style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2; opacity: 0" /><text
                x="68.3595096141599%" y="71" font-size="12px" fill="rgb(0.0, 138.56128015770727, 250.76166088685727)"
                id="_fs_qyoanfadzygaiohbyluo_ind_10" style="opacity: 0" dominant-baseline="middle"
                text-anchor="middle">-0.12</text><svg x="65.7495523679232%" y="40" height="20"
                width="5.219914492473407%"> <svg x="0" y="0" width="100%" height="100%"> <text x="50%" y="9"
                        font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle"
                        text-anchor="middle">you</text> </svg></svg>
            <line x1="70.96946686039661%" x2="74.19885616911931%" y1="60" y2="60" id="_fb_qyoanfadzygaiohbyluo_ind_9"
                style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2; opacity: 0" /><text
                x="72.58416151475797%" y="71" font-size="12px" fill="rgb(0.0, 138.56128015770727, 250.76166088685727)"
                id="_fs_qyoanfadzygaiohbyluo_ind_9" style="opacity: 0" dominant-baseline="middle"
                text-anchor="middle">-0.074</text><svg x="70.96946686039661%" y="40" height="20"
                width="3.229389308722702%"> <svg x="0" y="0" width="100%" height="100%"> <text x="50%" y="9"
                        font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle"
                        text-anchor="middle">if</text> </svg></svg>
            <line x1="74.19885616911931%" x2="74.61378498864252%" y1="60" y2="60" id="_fb_qyoanfadzygaiohbyluo_ind_4"
                style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2; opacity: 0" /><text
                x="74.40632057888092%" y="71" font-size="12px" fill="rgb(0.0, 138.56128015770727, 250.76166088685727)"
                id="_fs_qyoanfadzygaiohbyluo_ind_4" style="opacity: 0" dominant-baseline="middle"
                text-anchor="middle">-0.01</text><svg x="74.19885616911931%" y="40" height="20"
                width="0.4149288195232117%"> <svg x="0" y="0" width="100%" height="100%"> <text x="50%" y="9"
                        font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle"
                        text-anchor="middle">movie</text> </svg></svg>
            <line x1="74.61378498864252%" x2="75.02840113999885%" y1="60" y2="60" id="_fb_qyoanfadzygaiohbyluo_ind_11"
                style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2; opacity: 0" /><text
                x="74.82109306432068%" y="71" font-size="12px" fill="rgb(0.0, 138.56128015770727, 250.76166088685727)"
                id="_fs_qyoanfadzygaiohbyluo_ind_11" style="opacity: 0" dominant-baseline="middle"
                text-anchor="middle">-0.01</text><svg x="74.61378498864252%" y="40" height="20"
                width="0.4146161513563271%"> <svg x="0" y="0" width="100%" height="100%"> <text x="50%" y="9"
                        font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle"
                        text-anchor="middle">have</text> </svg></svg>
            <g transform="translate(-8,0)"> <svg x="60.47883153137376%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(-10,0)"> <svg x="60.47883153137376%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(-12,0)"> <svg x="60.47883153137376%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(-14,0)"> <svg x="60.47883153137376%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(2,0)"> <svg x="60.47883153137376%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(0,0)"> <svg x="60.47883153137376%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(-2,0)"> <svg x="60.47883153137376%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(-4,0)"> <svg x="60.47883153137376%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(-8,0)"> <svg x="65.7495523679232%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(-10,0)"> <svg x="65.7495523679232%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(-12,0)"> <svg x="65.7495523679232%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(-14,0)"> <svg x="65.7495523679232%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(2,0)"> <svg x="65.7495523679232%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(0,0)"> <svg x="65.7495523679232%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(-2,0)"> <svg x="65.7495523679232%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(-4,0)"> <svg x="65.7495523679232%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(-8,0)"> <svg x="70.96946686039661%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(-10,0)"> <svg x="70.96946686039661%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(-12,0)"> <svg x="70.96946686039661%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(-14,0)"> <svg x="70.96946686039661%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(2,0)"> <svg x="70.96946686039661%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(0,0)"> <svg x="70.96946686039661%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(-2,0)"> <svg x="70.96946686039661%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(-4,0)"> <svg x="70.96946686039661%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(-8,0)"> <svg x="74.19885616911931%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(-10,0)"> <svg x="74.19885616911931%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(-12,0)"> <svg x="74.19885616911931%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(-14,0)"> <svg x="74.19885616911931%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(2,0)"> <svg x="74.19885616911931%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(0,0)"> <svg x="74.19885616911931%" y="40" height="18" overflow="visible" width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2" />
                </svg></g>
            <g transform="translate(-2,0)"> <svg x="74.19885616911931%" y="40" height="18" overflow="visible"
                    width="30">
                    <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                        style="stroke:rgb(0.0, 138....jf_ind_1\').style.textDecoration = \'underline\';document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_1\').style.opacity = 1;document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_1\').style.opacity = 1;"
                        onmouseout="document.getElementById(\'_tp_lkgetdcqwkmsokaaiyjf_ind_1\').style.textDecoration = \'none\';document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_1\').style.opacity = 0;document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_1\').style.opacity = 0;"
                        style="fill:rgb(0,0,0,0)" />
                    <g transform="translate(-6.0,0)"> <svg x="86.81150087815516%" y="40" height="18" overflow="visible"
                            width="30">
                            <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                                style="stroke:rgb(208, 230, 250);stroke-width:2" />
                        </svg></g>
                    <rect x="84.93895214936954%" y="40" height="20" width="1.8725487287856168%"
                        onmouseover="document.getElementById(\'_tp_lkgetdcqwkmsokaaiyjf_ind_13\').style.textDecoration = \'underline\';document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_13\').style.opacity = 1;document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_13\').style.opacity = 1;"
                        onmouseout="document.getElementById(\'_tp_lkgetdcqwkmsokaaiyjf_ind_13\').style.textDecoration = \'none\';document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_13\').style.opacity = 0;document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_13\').style.opacity = 0;"
                        style="fill:rgb(0,0,0,0)" />
                    <g transform="translate(-6.0,0)"> <svg x="88.36729501245678%" y="40" height="18" overflow="visible"
                            width="30">
                            <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                                style="stroke:rgb(208, 230, 250);stroke-width:2" />
                        </svg></g>
                    <rect x="86.81150087815516%" y="40" height="20" width="1.555794134301621%"
                        onmouseover="document.getElementById(\'_tp_lkgetdcqwkmsokaaiyjf_ind_14\').style.textDecoration = \'underline\';document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_14\').style.opacity = 1;document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_14\').style.opacity = 1;"
                        onmouseout="document.getElementById(\'_tp_lkgetdcqwkmsokaaiyjf_ind_14\').style.textDecoration = \'none\';document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_14\').style.opacity = 0;document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_14\').style.opacity = 0;"
                        style="fill:rgb(0,0,0,0)" />
                    <g transform="translate(-6.0,0)"> <svg x="89.76051269160952%" y="40" height="18" overflow="visible"
                            width="30">
                            <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                                style="stroke:rgb(208, 230, 250);stroke-width:2" />
                        </svg></g>
                    <rect x="88.36729501245678%" y="40" height="20" width="1.393217679152741%"
                        onmouseover="document.getElementById(\'_tp_lkgetdcqwkmsokaaiyjf_ind_7\').style.textDecoration = \'underline\';document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_7\').style.opacity = 1;document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_7\').style.opacity = 1;"
                        onmouseout="document.getElementById(\'_tp_lkgetdcqwkmsokaaiyjf_ind_7\').style.textDecoration = \'none\';document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_7\').style.opacity = 0;document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_7\').style.opacity = 0;"
                        style="fill:rgb(0,0,0,0)" />
                    <g transform="translate(-6.0,0)"> <svg x="91.14932817745344%" y="40" height="18" overflow="visible"
                            width="30">
                            <path d="M 8 -9 l -6 18 L 8 25" fill="none"
                                style="stroke:rgb(208, 230, 250);stroke-width:2" />
                        </svg></g>
                    <rect x="89.76051269160952%" y="40" height="20" width="1.3888154858439208%"
                        onmouseover="document.getElementById(\'_tp_lkgetdcqwkmsokaaiyjf_ind_8\').style.textDecoration = \'underline\';document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_8\').style.opacity = 1;document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_8\').style.opacity = 1;"
                        onmouseout="document.getElementById(\'_tp_lkgetdcqwkmsokaaiyjf_ind_8\').style.textDecoration = \'none\';document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_8\').style.opacity = 0;document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_8\').style.opacity = 0;"
                        style="fill:rgb(0,0,0,0)" />
                    <rect x="91.14932817745344%" y="40" height="20" width="0.5173380007729094%"
                        onmouseover="document.getElementById(\'_tp_lkgetdcqwkmsokaaiyjf_ind_6\').style.textDecoration = \'underline\';document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_6\').style.opacity = 1;document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_6\').style.opacity = 1;"
                        onmouseout="document.getElementById(\'_tp_lkgetdcqwkmsokaaiyjf_ind_6\').style.textDecoration = \'none\';document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_6\').style.opacity = 0;document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_6\').style.opacity = 0;"
                        style="fill:rgb(0,0,0,0)" />
                </svg>
                <div align=\'center\'>
                    <div style="color: rgb(120,120,120); font-size: 12px; margin-top: -15px;">inputs</div>
                    <div style=\'display: inline; text-align: center;\'\n>
                        <div style=\'display: none; color: #999; padding-top: 0px; font-size: 12px;\'>0.0</div\n>
                            <div id=\'_tp_lkgetdcqwkmsokaaiyjf_ind_0\'\n style=\'display: inline; background:
                                rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius:
                                3px; padding: 0px\'\n
                                onclick="\n            if (this.previousSibling.style.display == \'none\') {\n                this.previousSibling.style.display = \'block\';\n                this.parentNode.style.display = \'inline-block\';\n            } else {\n                this.previousSibling.style.display = \'none\';\n                this.parentNode.style.display = \'inline\';\n            }"
                                \n
                                onmouseover="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_0\').style.opacity = 1; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_0\').style.opacity = 1;"
                                \n
                                onmouseout="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_0\').style.opacity = 0; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_0\').style.opacity = 0;"
                                \n></div>
                        </div>
                        <div style=\'display: inline; text-align: center;\'\n>
                            <div style=\'display: none; color: #999; padding-top: 0px; font-size: 12px;\'>-0.043</div\n>
                                <div id=\'_tp_lkgetdcqwkmsokaaiyjf_ind_1\'\n style=\'display: inline; background:
                                    rgba(30.0, 136.0, 229.0, 0.05407011289364222); border-radius: 3px; padding: 0px\'\n
                                    onclick="\n            if (this.previousSibling.style.display == \'none\') {\n                this.previousSibling.style.display = \'block\';\n                this.parentNode.style.display = \'inline-block\';\n            } else {\n                this.previousSibling.style.display = \'none\';\n                this.parentNode.style.display = \'inline\';\n            }"
                                    \n
                                    onmouseover="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_1\').style.opacity = 1; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_1\').style.opacity = 1;"
                                    \n
                                    onmouseout="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_1\').style.opacity = 0; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_1\').style.opacity = 0;"
                                    \n>What </div>
                            </div>
                            <div style=\'display: inline; text-align: center;\'\n>
                                <div style=\'display: none; color: #999; padding-top: 0px; font-size: 12px;\'>0.121
                                    </div\n>
                                    <div id=\'_tp_lkgetdcqwkmsokaaiyjf_ind_2\'\n style=\'display: inline; background:
                                        rgba(255.0, 13.0, 87.0, 0.15654585066349747); border-radius: 3px; padding:
                                        0px\'\n
                                        onclick="\n            if (this.previousSibling.style.display == \'none\') {\n                this.previousSibling.style.display = \'block\';\n                this.parentNode.style.display = \'inline-block\';\n            } else {\n                this.previousSibling.style.display = \'none\';\n                this.parentNode.style.display = \'inline\';\n            }"
                                        \n
                                        onmouseover="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_2\').style.opacity = 1; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_2\').style.opacity = 1;"
                                        \n
                                        onmouseout="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_2\').style.opacity = 0; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_2\').style.opacity = 0;"
                                        \n>a </div>
                                </div>
                                <div style=\'display: inline; text-align: center;\'\n>
                                    <div style=\'display: none; color: #999; padding-top: 0px; font-size: 12px;\'>0.74
                                        </div\n>
                                        <div id=\'_tp_lkgetdcqwkmsokaaiyjf_ind_3\'\n style=\'display: inline;
                                            background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding:
                                            0px\'\n
                                            onclick="\n            if (this.previousSibling.style.display == \'none\') {\n                this.previousSibling.style.display = \'block\';\n                this.parentNode.style.display = \'inline-block\';\n            } else {\n                this.previousSibling.style.display = \'none\';\n                this.parentNode.style.display = \'inline\';\n            }"
                                            \n
                                            onmouseover="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_3\').style.opacity = 1; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_3\').style.opacity = 1;"
                                            \n
                                            onmouseout="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_3\').style.opacity = 0; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_3\').style.opacity = 0;"
                                            \n>
                                            <grgfdsgeat>
                                        </div>
                                    </div>
                                    <div style=\'display: inline; text-align: center;\'\n>
                                        <div style=\'display: none; color: #999; padding-top: 0px; font-size: 12px;\'>
                                            0.74
                                            </div\n>
                                            <div id=\'_tp_lkgetdcqwkmsokaaiyjf_ind_3\'\n style=\'display: inline;
                                                background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding:
                                                0px\'\n
                                                onclick="\n            if (this.previousSibling.style.display == \'none\') {\n                this.previousSibling.style.display = \'block\';\n                this.parentNode.style.display = \'inline-block\';\n            } else {\n                this.previousSibling.style.display = \'none\';\n                this.parentNode.style.display = \'inline\';\n            }"
                                                \n
                                                onmouseover="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_3\').style.opacity = 1; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_3\').style.opacity = 1;"
                                                \n
                                                onmouseout="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_3\').style.opacity = 0; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_3\').style.opacity = 0;"
                                                \n>grgfdsgeat </div>
                                        </div>
                                        <div style=\'display: inline; text-align: center;\'\n>
                                            <div style=\'display: none; color: #999; padding-top: 0px; font-size:
                                                12px;\'>
                                                0.01</div\n>
                                                <div id=\'_tp_lkgetdcqwkmsokaaiyjf_ind_4\'\n style=\'display: inline;
                                                    background: rgba(255.0, 13.0, 87.0, 0.00677361853832443);
                                                    border-radius: 3px; padding: 0px\'\n
                                                    onclick="\n            if (this.previousSibling.style.display == \'none\') {\n                this.previousSibling.style.display = \'block\';\n                this.parentNode.style.display = \'inline-block\';\n            } else {\n                this.previousSibling.style.display = \'none\';\n                this.parentNode.style.display = \'inline\';\n            }"
                                                    \n
                                                    onmouseover="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_4\').style.opacity = 1; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_4\').style.opacity = 1;"
                                                    \n
                                                    onmouseout="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_4\').style.opacity = 0; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_4\').style.opacity = 0;"
                                                    \n>movie</div>
                                            </div>
                                            <div style=\'display: inline; text-align: center;\'\n>
                                                <div style=\'display: none; color: #999; padding-top: 0px; font-size:
                                                    12px;\'>-0.047</div\n>
                                                    <div id=\'_tp_lkgetdcqwkmsokaaiyjf_ind_5\'\n style=\'display:
                                                        inline; background: rgba(30.0, 136.0, 229.0,
                                                        0.06195286195286191); border-radius: 3px; padding: 0px\'\n
                                                        onclick="\n            if (this.previousSibling.style.display == \'none\') {\n                this.previousSibling.style.display = \'block\';\n                this.parentNode.style.display = \'inline-block\';\n            } else {\n                this.previousSibling.style.display = \'none\';\n                this.parentNode.style.display = \'inline\';\n            }"
                                                        \n
                                                        onmouseover="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_5\').style.opacity = 1; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_5\').style.opacity = 1;"
                                                        \n
                                                        onmouseout="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_5\').style.opacity = 0; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_5\').style.opacity = 0;"
                                                        \n>! </div>
                                                </div>
                                                <div style=\'display: inline; text-align: center;\'\n>
                                                    <div style=\'display: none; color: #999; padding-top: 0px;
                                                        font-size: 12px;\'>-0.01</div\n>
                                                        <div id=\'_tp_lkgetdcqwkmsokaaiyjf_ind_6\'\n style=\'display:
                                                            inline; background: rgba(30.0, 136.0, 229.0,
                                                            0.006773618538324436); border-radius: 3px; padding: 0px\'\n
                                                            onclick="\n            if (this.previousSibling.style.display == \'none\') {\n                this.previousSibling.style.display = \'block\';\n                this.parentNode.style.display = \'inline-block\';\n            } else {\n                this.previousSibling.style.display = \'none\';\n                this.parentNode.style.display = \'inline\';\n            }"
                                                            \n
                                                            onmouseover="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_6\').style.opacity = 1; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_6\').style.opacity = 1;"
                                                            \n
                                                            onmouseout="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_6\').style.opacity = 0; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_6\').style.opacity = 0;"
                                                            \n>.</div>
                                                    </div>
                                                    <div style=\'display: inline; text-align: center;\'\n>
                                                        <div style=\'display: none; color: #999; padding-top: 0px;
                                                            font-size: 12px;\'>-0.026</div\n>
                                                            <div id=\'_tp_lkgetdcqwkmsokaaiyjf_ind_7\'\n
                                                                style=\'display: inline; background: rgba(30.0, 136.0,
                                                                229.0, 0.03042186571598325); border-radius: 3px;
                                                                padding: 0px\'\n
                                                                onclick="\n            if (this.previousSibling.style.display == \'none\') {\n                this.previousSibling.style.display = \'block\';\n                this.parentNode.style.display = \'inline-block\';\n            } else {\n                this.previousSibling.style.display = \'none\';\n                this.parentNode.style.display = \'inline\';\n            }"
                                                                \n
                                                                onmouseover="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_7\').style.opacity = 1; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_7\').style.opacity = 1;"
                                                                \n
                                                                onmouseout="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_7\').style.opacity = 0; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_7\').style.opacity = 0;"
                                                                \n>.</div>
                                                        </div>
                                                        <div style=\'display: inline; text-align: center;\'\n>
                                                            <div style=\'display: none; color: #999; padding-top: 0px;
                                                                font-size: 12px;\'>-0.026</div\n>
                                                                <div id=\'_tp_lkgetdcqwkmsokaaiyjf_ind_8\'\n
                                                                    style=\'display: inline; background: rgba(30.0,
                                                                    136.0, 229.0, 0.03042186571598325); border-radius:
                                                                    3px; padding: 0px\'\n
                                                                    onclick="\n            if (this.previousSibling.style.display == \'none\') {\n                this.previousSibling.style.display = \'block\';\n                this.parentNode.style.display = \'inline-block\';\n            } else {\n                this.previousSibling.style.display = \'none\';\n                this.parentNode.style.display = \'inline\';\n            }"
                                                                    \n
                                                                    onmouseover="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_8\').style.opacity = 1; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_8\').style.opacity = 1;"
                                                                    \n
                                                                    onmouseout="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_8\').style.opacity = 0; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_8\').style.opacity = 0;"
                                                                    \n>.</div>
                                                            </div>
                                                            <div style=\'display: inline; text-align: center;\'\n>
                                                                <div style=\'display: none; color: #999; padding-top:
                                                                    0px; font-size: 12px;\'>0.074</div\n>
                                                                    <div id=\'_tp_lkgetdcqwkmsokaaiyjf_ind_9\'\n
                                                                        style=\'display: inline; background: rgba(255.0,
                                                                        13.0, 87.0, 0.09348385818974037); border-radius:
                                                                        3px; padding: 0px\'\n
                                                                        onclick="\n            if (this.previousSibling.style.display == \'none\') {\n                this.previousSibling.style.display = \'block\';\n                this.parentNode.style.display = \'inline-block\';\n            } else {\n                this.previousSibling.style.display = \'none\';\n                this.parentNode.style.display = \'inline\';\n            }"
                                                                        \n
                                                                        onmouseover="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_9\').style.opacity = 1; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_9\').style.opacity = 1;"
                                                                        \n
                                                                        onmouseout="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_9\').style.opacity = 0; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_9\').style.opacity = 0;"
                                                                        \n>if </div>
                                                                </div>
                                                                <div style=\'display: inline; text-align: center;\'\n>
                                                                    <div style=\'display: none; color: #999;
                                                                        padding-top: 0px; font-size: 12px;\'>0.12
                                                                        </div\n>
                                                                        <div id=\'_tp_lkgetdcqwkmsokaaiyjf_ind_10\'\n
                                                                            style=\'display: inline; background:
                                                                            rgba(255.0, 13.0, 87.0,
                                                                            0.15654585066349747); border-radius: 3px;
                                                                            padding: 0px\'\n
                                                                            onclick="\n            if (this.previousSibling.style.display == \'none\') {\n                this.previousSibling.style.display = \'block\';\n                this.parentNode.style.display = \'inline-block\';\n            } else {\n                this.previousSibling.style.display = \'none\';\n                this.parentNode.style.display = \'inline\';\n            }"
                                                                            \n
                                                                            onmouseover="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_10\').style.opacity = 1; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_10\').style.opacity = 1;"
                                                                            \n
                                                                            onmouseout="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_10\').style.opacity = 0; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_10\').style.opacity = 0;"
                                                                            \n>you </div>
                                                                    </div>
                                                                    <div style=\'display: inline; text-align:
                                                                        center;\'\n>
                                                                        <div style=\'display: none; color: #999;
                                                                            padding-top: 0px; font-size: 12px;\'>0.01
                                                                            </div\n>
                                                                            <div id=\'_tp_lkgetdcqwkmsokaaiyjf_ind_11\'\n
                                                                                style=\'display: inline; background:
                                                                                rgba(255.0, 13.0, 87.0,
                                                                                0.00677361853832443); border-radius:
                                                                                3px; padding: 0px\'\n
                                                                                onclick="\n            if (this.previousSibling.style.display == \'none\') {\n                this.previousSibling.style.display = \'block\';\n                this.parentNode.style.display = \'inline-block\';\n            } else {\n                this.previousSibling.style.display = \'none\';\n                this.parentNode.style.display = \'inline\';\n            }"
                                                                                \n
                                                                                onmouseover="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_11\').style.opacity = 1; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_11\').style.opacity = 1;"
                                                                                \n
                                                                                onmouseout="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_11\').style.opacity = 0; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_11\').style.opacity = 0;"
                                                                                \n>have </div>
                                                                        </div>
                                                                        <div style=\'display: inline; text-align:
                                                                            center;\'\n>
                                                                            <div style=\'display: none; color: #999;
                                                                                padding-top: 0px; font-size: 12px;\'>
                                                                                -0.274
                                                                                </div\n>
                                                                                <div id=\'_tp_lkgetdcqwkmsokaaiyjf_ind_12\'\n
                                                                                    style=\'display: inline; background:
                                                                                    rgba(30.0, 136.0, 229.0,
                                                                                    0.36938007526242816); border-radius:
                                                                                    3px; padding: 0px\'\n
                                                                                    onclick="\n            if (this.previousSibling.style.display == \'none\') {\n                this.previousSibling.style.display = \'block\';\n                this.parentNode.style.display = \'inline-block\';\n            } else {\n                this.previousSibling.style.display = \'none\';\n                this.parentNode.style.display = \'inline\';\n            }"
                                                                                    \n
                                                                                    onmouseover="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_12\').style.opacity = 1; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_12\').style.opacity = 1;"
                                                                                    \n
                                                                                    onmouseout="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_12\').style.opacity = 0; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_12\').style.opacity = 0;"
                                                                                    \n>no </div>
                                                                            </div>
                                                                            <div style=\'display: inline; text-align:
                                                                                center;\'\n>
                                                                                <div style=\'display: none; color: #999;
                                                                                    padding-top: 0px; font-size:
                                                                                    12px;\'>
                                                                                    -0.035</div\n>
                                                                                    <div id=\'_tp_lkgetdcqwkmsokaaiyjf_ind_13\'\n
                                                                                        style=\'display: inline;
                                                                                        background: rgba(30.0, 136.0,
                                                                                        229.0, 0.04618736383442258);
                                                                                        border-radius: 3px; padding:
                                                                                        0px\'\n
                                                                                        onclick="\n            if (this.previousSibling.style.display == \'none\') {\n                this.previousSibling.style.display = \'block\';\n                this.parentNode.style.display = \'inline-block\';\n            } else {\n                this.previousSibling.style.display = \'none\';\n                this.parentNode.style.display = \'inline\';\n            }"
                                                                                        \n
                                                                                        onmouseover="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_13\').style.opacity = 1; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_13\').style.opacity = 1;"
                                                                                        \n
                                                                                        onmouseout="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_13\').style.opacity = 0; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_13\').style.opacity = 0;"
                                                                                        \n>taste</div>
                                                                                </div>
                                                                                <div style=\'display: inline;
                                                                                    text-align: center;\'\n>
                                                                                    <div style=\'display: none; color:
                                                                                        #999; padding-top: 0px;
                                                                                        font-size: 12px;\'>0.8</div\n>
                                                                                        <div id=\'_tp_lkgetdcqwkmsokaaiyjf_ind_14\'\n
                                                                                            style=\'display: inline;
                                                                                            background: rgba(255.0,
                                                                                            235.0, 59.0, 0.2);
                                                                                            border-radius: 3px; padding:
                                                                                            0px\'\n
                                                                                            onclick="\n            if (this.previousSibling.style.display == \'none\') {\n                this.previousSibling.style.display = \'block\';\n                this.parentNode.style.display = \'inline-block\';\n            } else {\n                this.previousSibling.style.display = \'none\';\n                this.parentNode.style.display = \'inline\';\n            }"
                                                                                            \n
                                                                                            onmouseover="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_14\').style.opacity = 1; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_14\').style.opacity = 1;"
                                                                                            \n
                                                                                            onmouseout="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_14\').style.opacity = 0; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_14\').style.opacity = 0;"
                                                                                            \n><br></div>
                                                                                    </div>

                                                                                    <div style=\'display: inline;
                                                                                        text-align: center;\'\n>
                                                                                        <div style=\'display: none;
                                                                                            color: #999; padding-top:
                                                                                            0px; font-size: 12px;\'>
                                                                                            -0.029</div\n>
                                                                                            <div id=\'_tp_lkgetdcqwkmsokaaiyjf_ind_15\'\n
                                                                                                style=\'display: inline;
                                                                                                background: rgba(30.0,
                                                                                                136.0, 229.0,
                                                                                                0.03830461477520309);
                                                                                                border-radius: 3px;
                                                                                                padding: 0px\'\n
                                                                                                onclick="\n            if (this.previousSibling.style.display == \'none\') {\n                this.previousSibling.style.display = \'block\';\n                this.parentNode.style.display = \'inline-block\';\n            } else {\n                this.previousSibling.style.display = \'none\';\n                this.parentNode.style.display = \'inline\';\n            }"
                                                                                                \n
                                                                                                onmouseover="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_15\').style.opacity = 1; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_15\').style.opacity = 1;"
                                                                                                \n
                                                                                                onmouseout="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_15\').style.opacity = 0; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_15\').style.opacity = 0;"
                                                                                                \n>.</div>
                                                                                        </div>
                                                                                        <div style=\'display: inline;
                                                                                            text-align: center;\'\n>
                                                                                            <div style=\'display: none;
                                                                                                color: #999;
                                                                                                padding-top: 0px;
                                                                                                font-size: 12px;\'>0.0
                                                                                                </div\n>
                                                                                                <div id=\'_tp_lkgetdcqwkmsokaaiyjf_ind_16\'\n
                                                                                                    style=\'display:
                                                                                                    inline; background:
                                                                                                    rgba(230.2941176470614,
                                                                                                    26.505882352939775,
                                                                                                    102.59215686274348,
                                                                                                    0.0); border-radius:
                                                                                                    3px; padding:
                                                                                                    0px\'\n
                                                                                                    onclick="\n            if (this.previousSibling.style.display == \'none\') {\n                this.previousSibling.style.display = \'block\';\n                this.parentNode.style.display = \'inline-block\';\n            } else {\n                this.previousSibling.style.display = \'none\';\n                this.parentNode.style.display = \'inline\';\n            }"
                                                                                                    \n
                                                                                                    onmouseover="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_16\').style.opacity = 1; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_16\').style.opacity = 1;"
                                                                                                    \n
                                                                                                    onmouseout="document.getElementById(\'_fb_lkgetdcqwkmsokaaiyjf_ind_16\').style.opacity = 0; document.getElementById(\'_fs_lkgetdcqwkmsokaaiyjf_ind_16\').style.opacity = 0;"
                                                                                                    \n></div>
                                                                                            </div>
                                                                                        </div>
                                                                                    </div>
                                                                                </div>'"""

# %%
ipython_display(HTML(out))
# Out:
# '<div align='center'>
#
#     <script>
#     document._hover_magufbxjkoumibqnftcf = '_tp_magufbxjkoumibqnftcf_output_0';
#     document._zoom_magufbxjkoumibqnftcf = undefined;
#     function _output_onclick_magufbxjkoumibqnftcf(i) {
#         var next_id = undefined;
#
#         if (document._zoom_magufbxjkoumibqnftcf !== undefined) {
#             document.getElementById(document._zoom_magufbxjkoumibqnftcf+ '_zoom').style.display = 'none';
#
#             if (document._zoom_magufbxjkoumibqnftcf === '_tp_magufbxjkoumibqnftcf_output_' + i) {
#                 document.getElementById(document._zoom_magufbxjkoumibqnftcf).style.display = 'block';
#                 document.getElementById(document._zoom_magufbxjkoumibqnftcf+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_magufbxjkoumibqnftcf).style.display = 'none';
# ...

# %%
shap.plots.text(
    shap.Explanation(
        values=text_shap_vals[idx].values,
        base_values=text_shap_vals[idx].base_values,
        data=text_shap_vals[idx].data,
        # clustering=text_shap_vals.clustering[idx],
        output_names=["Genre is not Drama", "Genre is Drama"],
        # hierarchical_values=text_shap_vals[idx].hierarchical_values,
    )
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 shap.plots.text(
#       2     shap.Explanation(
#       3         values=text_shap_vals[idx].values,
#       4         base_values=text_shap_vals[idx].base_values,
#       5         data=text_shap_vals[idx].data,
#       6         # clustering=text_shap_vals.clustering[idx],
#       7         output_names=["Genre is not Drama", "Genre is Drama"],
#       8         # hierarchical_values=text_shap_vals[idx].hierarchical_values,
#       9     )
#      10 )
#
# NameError: name 'shap' is not defined
